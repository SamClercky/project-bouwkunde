# %%
# Load extensions
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# Importeren van bibliotheken
import matplotlib.pyplot as plt

import analyse_utils as utils

plt.style.use("classic")

# %% [markdown]
# # Analyse van bruggen
#
# Opsommingen van een aantal interessante verbanden om
# te kunnen besluiten waar de beste bruggen liggen (beste parameters)

# %% [markdown]
# ## Eerste simulatie

# %%
bruggen1 = utils.read_from_file("bruggen.txt")
utils.create_rapport(bruggen1)
# Out:
# /usr/local/lib/python3.9/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %% [markdown]
# ## Tweede simulatie

# %%
bruggen2 = utils.read_from_file("bruggen2.txt")
utils.create_rapport(bruggen2)

# %% [markdown]
# ## Derde simulatie

# %%
bruggen3 = utils.read_from_file("bruggen3.txt")
utils.create_rapport(bruggen3)

# %%
bruggen4 = utils.read_from_file("bruggen4.txt")
utils.create_rapport(bruggen4)

# %%
bruggen5 = utils.read_from_file("bruggen5.txt")
utils.create_rapport(bruggen5)

# %%
bruggen6 = utils.read_from_file("bruggen6.txt")
utils.create_rapport(bruggen6)

# %%
bruggen7 = utils.read_from_file("bruggen7.txt")
utils.create_rapport(bruggen7)
