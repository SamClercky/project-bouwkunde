# %%
# Load extensions
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# Importeren van bibliotheken
import math
import numpy as np
import matplotlib.pyplot as plt

from berekeningen_andreas import Brug

plt.style.use("classic")

# %% [markdown]
# # Zoeken van meest ideale parameters voor brug
# ## Exploratie van formules
# ### Probleemstelling
# Berekeningen gaan uit van volgende situatie:
# ![Berekeningen](../figures/berekeningen_andreas2.0.svg)

# %%
brug = Brug(3, 0.3, 2, 2, 0.1, 0.1, 5)
brug.__dict__
# Out:
# {'h1': 3,
#  'h2': 0.3,
#  'd1a': 2,
#  'd2a': 2,
#  'd1b': 0.1,
#  'd2b': 0.1,
#  'N': 5,
#  'cosa': 0.5854905538443584,
#  'sina': 0.8106792283998809,
#  'cosb': 0.9905498667663629,
#  'sinb': 0.13715305847534254}

# %%
Va, Vb, Fi = brug.calc_reactie_krachten()
Va, Vb, Fi
# Out:
# (68.55, 68.55, [137.10000000000008, 337.09999999999997, 137.1, 137.1, 137.1])

# %%
FiA, FiB = brug.calc_touw_kracht()
FiA, FiB
# Out:
# ((153.74313201828426,
#   378.0219533432793,
#   153.74313201828414,
#   153.74313201828414,
#   153.74313201828414),
#  (90.87392218728458,
#   223.4398188864596,
#   90.87392218728452,
#   90.87392218728452,
#   90.87392218728452))

# %%
brug.calc_kant()
# Out:
# (-325.725677830941,
#  -581.3888888888889,
#  (90.01515151515157,
#   232.1018312525095,
#   106.46520751775516,
#   123.9958932734363,
#   145.02130581506853),
#  -32.5725677830941,
#  -581.3888888888889,
#  (90.01515151515157,
#   221.4386129215654,
#   90.19450444118374,
#   90.4181953080214,
#   90.73043601061225))

# %% [markdown]
# ### Wegdek

# %%
x = np.arange(0, 2, 0.001)
N, D, M = list(zip(*[brug.calc_intern_wegdek(xi) for xi in x]))

fig = plt.figure()
fig.suptitle("Interne krachten wegdek")
ax1 = plt.subplot(3,1,1)
ax1.plot(x, N)
ax1.set_ylabel("N")
ax2 = plt.subplot(3,1,2, sharex=ax1)
ax2.plot(x, D)
ax2.set_ylabel("D")
ax2.plot(x, [0]*len(x))
ax3 = plt.subplot(3,1,3, sharex=ax1)
ax3.plot(x, [-m for m in M])
ax3.set_ylabel("M")
plt.savefig("figs/wegdek-andreas")

# %% [markdown]
# ### Doorbuiging wegdek

# %%
x = np.arange(0, 2, 0.001)
f = [brug.calc_doorbuiging_wegdek(xi)*10**3 for xi in x]

plt.plot(x, f)
plt.title("Maximale doorbuiging wegdek")
plt.xlabel("x (m)")
plt.ylabel("Doorbuiging (mm)")
plt.savefig("figs/wegdek-doorbuiging-ramses")

# %% [markdown]
# ### Piloon 1

# %%
x = np.arange(0, brug.h1, 0.001)
N, D, M = list(zip(*[brug.calc_intern_balk(xi, True) for xi in x]))

fig = plt.figure()
fig.suptitle("Interne krachten piloon1")
ax1 = plt.subplot(3,1,1)
ax1.plot(x, N)
ax1.plot(x, [0]*len(x))
ax1.set_ylabel("N")
ax2 = plt.subplot(3,1,2)
ax2.plot(x, D)
ax2.set_ylabel("D")
ax3 = plt.subplot(3,1,3)
ax3.plot(x, M)
ax3.set_ylabel("M")
plt.savefig("figs/piloon1-andreas")

# %% [markdown]
# ### Piloon 2

# %%
x = np.arange(0, brug.h2, 0.001)
N, D, M = list(zip(*[brug.calc_intern_balk(xi, False) for xi in x]))

fig = plt.figure()
fig.suptitle("Interne krachten piloon2")
ax1 = plt.subplot(3,1,1)
ax1.plot(x, N)
ax1.plot(x, [0]*len(x))
ax1.set_ylabel("N")
ax2 = plt.subplot(3,1,2)
ax2.plot(x, D)
ax2.set_ylabel("D")
ax3 = plt.subplot(3,1,3)
ax3.plot(x, M)
ax3.set_ylabel("M")
plt.savefig("figs/piloon2-andreas")

# %% [markdown]
# ## Optimalisatie

# %%
import genetic_algo as ga

# Maxwaarden
h1_max = 2 # 2m
h2_max = 2 # 2m
h1_min = 0.06 # 6cm
h2_min = 0.06 # 6cm
d1_max = 2 # 2m
d2_max = 2 # 2m
d1_min = 0.1 # 10cm
d2_min = 0.1 # 10cm
N_max = 10
N_min = 1

# %%
population = [ga.genRandomBrugA() for i in range(100)] # Populatie van 100

# %%
for i in range(100): # 1000 generations
    print('.', end="")
    population = ga.kill_population(population)
    population = ga.regen_population(population,
                                    ga.genRandomBrugA,
                                    ga.genFromParentsA)
# Out:
# ....................................................................................................

# %%
best = ga.find_best(population)

# %%
ga.print_brug(best[1])
print(f"Score brug: {best[0]}")
# Out:
# ======= Info Brug ========
# h1:	2
# h2:	0.06
# d1a:	2.1
# d2a:	1.2227541703900056
# d1b:	2
# d2b:	1.1227541703900055
# N:	1
# Krachten in touwen A
# 	941.9165621842586
# Krachten in touwen B
# 	784.034955731993
# Krachten in touwen C
# 	783.7219528071023
# Krachten in touwen D
# 	783.7219528071023
# Maximale kracht trek/druk:
# 	N1: 794.7979685380681
# 	N2: 227.8020314619317
# 	D: 338.5720333333334
# Score brug: 2343.053333333333

# %% [markdown]
# ### Enkele berekende bruggen
# ```
# ======= Info Brug ========
# h1:	0.06
# h2:	1.1318279861842355
# d1a:	2.1
# d2a:	2
# d1b:	2
# d2b:	0.1
# N:	2
# Krachten in touwen A
# 	-387.5154756748858
# 	-387.5154756748858
# Krachten in touwen B
# 	481.6223405629876
# 	481.6223405629876
# Krachten in touwen C
# 	-387.4909555386635
# 	-404.5524345254277
# Krachten in touwen D
# 	387.4909555386635
# 	404.3137722413377
# Maximale kracht trek/druk:
# 	N1: 140.8333333333333
# 	N2: 828.2991889220579
# 	D: 340.6925000000001
# Score brug: 2023.8019246879646
# ```
# ```
# ======= Info Brug ========
# h1:	0.06
# h2:	1.0652839017460745
# d1:	0.1
# d2:	2
# N:	2
# Krachten in touwen A
# 	-708.0892728345934
# 	-708.0892728345934
# Krachten in touwen B
# 	905.4218833682901
# 	905.4218833682901
# Krachten in touwen C
# 	-707.3734194648738
# 	-738.5195315469434
# Krachten in touwen D
# 	707.3734194648738
# 	732.0296004492964
# Maximale kracht trek/druk:
# 	N1: 266.6666666666666
# 	N2: 1585.3853201549225
# 	D: 666.4000000000001
# Score brug: 3856.0163142124156
# ```
# ```
# ======= Info Brug ========
# h1:	1.126803803965232
# h2:	0.06
# d1:	2
# d2:	0.1
# N:	2
# Krachten in touwen A
# 	872.737237017732
# 	872.737237017732
# Krachten in touwen B
# 	-667.255538772807
# 	-667.255538772807
# Krachten in touwen C
# 	666.5809668731615
# 	692.5245096390946
# Krachten in touwen D
# 	-666.5809668731615
# 	-695.9309607161756
# Score brug: 3875.5966914564374
# ```
# ```
# ======= Info Brug ========
# h1:	0.06
# h2:	1.2516051534550352
# d1:	0.1
# d2:	2
# N:	2
# Krachten in touwen A
# 	-597.3713229720112
# 	-597.3713229720112
# Krachten in touwen B
# 	818.4997111963966
# 	818.4997111963966
# Krachten in touwen C
# 	-596.7674015585268
# 	-623.0434586797123
# Krachten in touwen D
# 	596.7674015585268
# 	625.2992554442243
# Maximale kracht trek/druk:
# 	N1: 266.6666666666666
# 	N2: 1573.7716882747561
# 	D: 666.4000000000001
# Score brug: 3909.1072028074623
# ```
# ```
# ======= Info Brug ========
# h1:	1.572067987257989
# h2:	0.06
# d1:	2
# d2:	0.1
# N:	2
# Krachten in touwen A
# 	727.0758927725531
# 	727.0758927725531
# Krachten in touwen B
# 	-470.76636300630054
# 	-470.76636300630054
# Krachten in touwen C
# 	470.2904347579321
# 	505.30783775277274
# Krachten in touwen D
# 	-470.290434757932
# 	-490.997628708161
# Score brug: 3969.8161468717476
# ```
# ```
# ======= Info Brug ========
# h1:	0.8867440380990106
# h2:	0.06
# d1:	2
# d2:	0.1
# N:	2
# Krachten in touwen A
# 	1032.9862077900755
# 	1032.9862077900755
# Krachten in touwen B
# 	-861.0049957136215
# 	-861.0049957136215
# Krachten in touwen C
# 	860.1345499221471
# 	881.0165881426548
# Krachten in touwen D
# 	-860.1345499221471
# 	-898.0068340091038
# Maximale kracht trek/druk:
# 	N1: 1601.4252388529362
# 	N2: 266.6666666666667
# 	D: 666.4000000000001
# Score brug: 3980.4220933118136
# ```
# ```
# ======= Info Brug ========
# h1:	2
# h2:	0.06
# d1:	2
# d2:	0.1
# N:	2
# Krachten in touwen A
# 	660.8112303255878
# 	660.8112303255878
# Krachten in touwen B
# 	-366.92306545345394
# 	-366.92306545345394
# Krachten in touwen C
# 	366.55211912943855
# 	409.8177278350128
# Krachten in touwen D
# 	-366.5521191294386
# 	-382.69164752020333
# Maximale kracht trek/druk:
# 	N1: 1549.5990836197016
# 	N2: 266.6666666666667
# 	D: 666.4000000000001
# Score brug: 4019.610538373424
# ```
