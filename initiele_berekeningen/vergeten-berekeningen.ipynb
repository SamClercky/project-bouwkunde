# %%
# Load extensions
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# Importeren van bibliotheken
import math
import numpy as np
import matplotlib.pyplot as plt
import constanten as C

plt.style.use("classic")

# %%
# Doorbuiging zwaarste punt in 3D
I = 2*C.H_WEGDEK**3/12
E = C.E_MODULUS
Q = C.VERDEELDE_BELASTING/2+C.EIG_GEWICHT_BRUG
P = C.PUNT_BELASTING/2

D = lambda L: (5*Q*L**4)/(384*E*I) + (5*P*L**3)/(48*E*I)

x = np.arange(0, 0.4, 0.0001)
plt.plot(x, [D(i)*1000 for i in x])
plt.title("Doorbuiging in 3D meest belaste punt")
plt.ylabel("Doorbuiging [mm]")
plt.xlabel("Ophangpunten tov midden van brug [m]")
# Out:
# Text(0.5, 0, 'Ophangpunten tov midden van brug [m]')

# %%
l = np.arange(0.01, 2, 0.01)
P = np.math.pi**2 * C.I_WEGDEK / l**2

plt.plot(l, P*C.H_WEGDEK*C.B_WEGDEK)
plt.title("Knikspanning tov lengte wegdek met C=1")
plt.xlabel("Lengte wegdek [m]")
plt.ylabel("Maximale knikkracht [N]")
# Out:
# Text(0, 0.5, 'Maximale knikkracht [N]')
