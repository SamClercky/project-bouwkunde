# %%
# Load extensions
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from proces_data import *

# %%
df = import_data("../clean_csv/sample18mm-tension-G3b_1_1.csv")
df
# Out:
#          Time  Displacement   Force  Strain 1
# 0       0.000  0.000000e+00    99.2   -0.0049
# 1       0.020  0.000000e+00    99.3   -0.0049
# 2       0.040  0.000000e+00    99.6   -0.0050
# 3       0.060  0.000000e+00    99.6   -0.0049
# 4       0.080  1.000000e-07    99.8   -0.0049
# ...       ...           ...     ...       ...
# 7312  146.240  2.437000e-03  2672.3    0.8483
# 7313  146.260  2.437300e-03  2671.6    0.8482
# 7314  146.280  2.437600e-03  2671.3    0.8481
# 7315  146.297  2.437900e-03  2014.5    0.6644
# 7316  146.303  2.438000e-03  1558.7    0.4653
#
# [7317 rows x 4 columns]

# %%
# Constanten aan experiment
DOORSNEDE = (18*6)/1000
CUT_OF_POINT = 7200

calc_E(df, DOORSNEDE, CUT_OF_POINT)
# Out:
# {'E-modulus': 9585431.199779276, 'stderr': 15090.748886291354}
