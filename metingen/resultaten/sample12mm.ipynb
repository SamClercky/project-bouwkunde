# %%
# Load extensions
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from proces_data import *

# %%
df = import_data("../clean_csv/sample12mm-tension-G3b_1.csv")
df
# Out:
#          Time  Displacement  Force  Strain 1
# 0       0.000  0.000000e+00  243.4   -0.0007
# 1       0.020  0.000000e+00  244.2   -0.0007
# 2       0.040  0.000000e+00  244.4   -0.0007
# 3       0.060  1.000000e-07  244.0   -0.0007
# 4       0.080  1.000000e-07  243.5   -0.0007
# ...       ...           ...    ...       ...
# 8224  164.461  2.740700e-03   -0.3   -0.3046
# 8225  164.481  2.741000e-03    1.1   -0.3046
# 8226  164.501  2.741300e-03    0.9   -0.3047
# 8227  164.521  2.741700e-03    0.4   -0.3047
# 8228  164.529  2.741800e-03    0.4   -0.3048
#
# [8229 rows x 4 columns]

# %%
# Constanten aan experiment
DOORSNEDE = (12*6)/1000
CUT_OF_POINT = 7200

calc_E(df, DOORSNEDE, CUT_OF_POINT)
# Out:
# {'E-modulus': 11982218.674363868, 'stderr': 16111.255053872272}
